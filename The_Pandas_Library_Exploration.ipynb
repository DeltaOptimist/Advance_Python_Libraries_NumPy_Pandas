# %% [markdown]
# **Pandas: The Python Data Analysis Library**
#
#
# Pandas is an open source Python library for highly specialized data analysis. Currently it is the reference point that all professionals using the Python language need to study and analyze data sets for statistical purposes of analysis and decision making.
#
# This library has been designed and developed primarily by Wes McKinney starting in 2008; later, in 2012, Sien Chang, one of his colleagues, was added to the development. Together they set up one of the most used libraries in the Python community.
#
# **Pandas arises from the need to have a specific library for analysis of the data which provides, in the simplest possible way, all the instruments for the processing of data, data extraction, and data manipulation.**
#
#
# This Python package is designed on the basis of the NumPy library.

# %% [markdown]
# **Installation**
#
# The easiest and most general way to install the pandas library is to use a prepackaged solution, i.e., installing it through the distribution Anaconda
#
# **Enter the following command:**
#
# *conda install pandas*
#
# If you want to **upgrade your package** to a newer version, the command is very simple and intuitive:
#
# *conda update pandas*
#
#
# **Installation from PyPI**
#
# pandas can also be installed by PyPI:
#
# *pip install pandas*

# %%
# Getting Started with pandas

# First, open a session on the Python shell and then import the pandas library.

import pandas as pd
import numpy as np

# from pandas import *

# %% [markdown]
# **Introduction to pandas Data Structures**
#
# The heart of pandas is just the two primary data structures on which all transactions, which are generally made during the analysis of data, are centralized:
#
# **Series**
# **DataFrame**
#
#
#
#
# **The Series**
#
# The Series is the object of the pandas library designed to represent one-dimensional data structures, similarly to an array but with some additional features. Its internal structure is simple  and is composed of two arrays associated with each other. The main array has the purpose to hold the data (data of any NumPy type) to which each element is associated with a label, contained within the other array, called the Index.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Declaring a Series
#
# To create the Series as specified in, simply call the Series( ) constructor passing as an argument an array containing the values to be included in it.

# %%
import pandas as pd 
import numpy as np
s = pd.Series([12,-4,7,9])
s
# Out:
# 0    12
# 1    -4
# 2     7
# 3     9
# dtype: int64

# %%
s = pd.Series([12,-4,7,9], index=['a','b','c','d'])
s
# Out:
# a    12
# b    -4
# c     7
# d     9
# dtype: int64

# %%
s.values
# Out:
# array([12, -4,  7,  9])

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
s[2]
# Out:
# 7

# %%
#index
s['b']
# Out:
# -4

# %%
# In the same way you select multiple items in a numpy array, you can specify the following:

s[0:2]
# Out:
# a    12
# b    -4
# dtype: int64

# %%
# or even in this case, use the corresponding labels, but specifying the list of labels within an array.
s[['b','c']]
# Out:
# b   -4
# c    7
# dtype: int64

# %%
# Assigning Values to the Elements
s[1] = 0
s
# Out:
# a    12
# b     0
# c     7
# d     9
# dtype: int64

# %%
s['b'] = 1
s
# Out:
# a    12
# b     1
# c     7
# d     9
# dtype: int64

# %%
# Defining Series from NumPy Arrays and Other Series

arr = np.array([1,2,3,4])
s3 = pd.Series(arr)
s3
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s3
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
arr[2] = -2

s3
# Out:
# 0    1
# 1    2
# 2   -2
# 3    4
# dtype: int64

# %%
# Filtering Values
s[s > 8]
# Out:
# a    12
# d     9
# dtype: int64

# %%
# Operations and Mathematical Functions


s / 2
# Out:
# a    6.0
# b    0.5
# c    3.5
# d    4.5
# dtype: float64

# %%
np.log(s)
# Out:
# a    2.484907
# b    0.000000
# c    1.945910
# d    2.197225
# dtype: float64

# %%
# Evaluating Values'

eva = pd.Series([1,0,2,1,2,3], index=['white','white','blue','green','green','yellow'])
eva
# Out:
# white     1
# white     0
# blue      2
# green     1
# green     2
# yellow    3
# dtype: int64

# %%
eva.unique()
# Out:
# array([1, 0, 2, 3])

# %%
eva.value_counts()
# Out:
# 1    2
# 2    2
# 0    1
# 3    1
# dtype: int64

# %%
eva.isna()
# Out:
# white     False
# white     False
# blue      False
# green     False
# green     False
# yellow    False
# dtype: bool

# %%
# NaN Values

# NaN (Not a Number)

s2 = pd.Series([5,-3,np.NaN,14])

s2
# Out:
# 0     5.0
# 1    -3.0
# 2     NaN
# 3    14.0
# dtype: float64

# %%
# The isnull( ) and notnull( ) functions are very useful to identify the indexes without a value.

s2.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
s2.notnull()
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
s2[s2.notnull()]
# Out:
# 0     5.0
# 1    -3.0
# 3    14.0
# dtype: float64

# %%
s2[s2.isnull()]
# Out:
# 2   NaN
# dtype: float64

# %%
# Series as Dictionaries

mydict = {'red': 2000, 'blue': 1000, 'yellow': 500, 'orange': 1000}

myseries = pd.Series(mydict)
myseries
# Out:
# red       2000
# blue      1000
# yellow     500
# orange    1000
# dtype: int64

# %%
colors = ['red','yellow','orange','blue','green']
myseries1 = pd.Series(mydict, index=colors)
myseries1
# Out:
# red       2000.0
# yellow     500.0
# orange    1000.0
# blue      1000.0
# green        NaN
# dtype: float64

# %%
# Operations between Series


mydict2 = {'red':400,'yellow':1000,'black':700}
myseries2 = pd.Series(mydict2)

myseries + myseries2
# Out:
# black        NaN
# blue         NaN
# orange       NaN
# red       2400.0
# yellow    1500.0
# dtype: float64

# %% [markdown]
# **The DataFrame**
#
#
# The DataFrame is a tabular data structure very similar to the Spreadsheet (the most familiar are Excel spreadsheets).
#
# This data structure is designed to extend the case of the Series to multiple dimensions.
#
# In fact, the DataFrame consists of an ordered collection of columns, each of which can contain a value of different type (numeric, string, Boolean, etc.).
#
# Unlike Series, which had an Index array containing labels associated with each element, in the case of the data frame, there are two index arrays. The first, associated with the lines, has very similar functions to the index array in Series.
#
# In fact, each label is associated with all the values in the row. The second array instead contains a series of labels, each associated with a particular column.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A DataFrame may also be understood as a dict of Series, where the keys are the column names and values are the Series that will form the columns of the data frame.

# %%
# Defining a DataFrame
import pandas as pd
import numpy as np

data = {'color' : ['blue','green','yellow','red','white'],
                     'object' : ['ball','pen','pencil','paper','mug'],
                     'price' : [1.2,1.0,0.6,0.9,1.7]}

frame = pd.DataFrame(data)
frame
# Out:
#     color  object  price
# 0    blue    ball    1.2
# 1   green     pen    1.0
# 2  yellow  pencil    0.6
# 3     red   paper    0.9
# 4   white     mug    1.7

# %%
import pandas as pd

frame2 = pd.DataFrame(data, index=['one','two','three','four','five'])
frame2
# Out:
#         color  object  price
# one      blue    ball    1.2
# two     green     pen    1.0
# three  yellow  pencil    0.6
# four      red   paper    0.9
# five    white     mug    1.7

# %%
import pandas as pd
import numpy as np
frame3 = pd.DataFrame(np.arange(16).reshape((4,4)),
                   index=['red','blue','yellow','white'],
                   columns=['ball','pen','pencil','paper']) 
frame3
# Out:
#         ball  pen  pencil  paper
# red        0    1       2      3
# blue       4    5       6      7
# yellow     8    9      10     11
# white     12   13      14     15

# %%
# Selecting Elements

frame.columns
# Out:
# Index(['color', 'object', 'price'], dtype='object')

# %%
frame.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
frame.values
# Out:
# array([['blue', 'ball', 1.2],
#        ['green', 'pen', 1.0],
#        ['yellow', 'pencil', 0.6],
#        ['red', 'paper', 0.9],
#        ['white', 'mug', 1.7]], dtype=object)

# %%
frame['price']
# Out:
# 0    1.2
# 1    1.0
# 2    0.6
# 3    0.9
# 4    1.7
# Name: price, dtype: float64

# %%
frame.price
# Out:
# 0    1.2
# 1    1.0
# 2    0.6
# 3    0.9
# 4    1.7
# Name: price, dtype: float64

# %%
frame[0:2]
# Out:
#    color object  price
# 0   blue   ball    1.2
# 1  green    pen    1.0

# %%
# desired block of data

frame['object'][3]
# Out:
# 'paper'

# %%
# Assigning Values

frame.index.name = 'id'; frame.columns.name = 'item'
frame
# Out:
# item   color  object  price
# id
# 0       blue    ball    1.2
# 1      green     pen    1.0
# 2     yellow  pencil    0.6
# 3        red   paper    0.9
# 4      white     mug    1.7

# %%
 # You can do this by simply assigning a value to the instance of the DataFrame specifying a new column name.
 frame['new'] = 12
 frame
# Out:
# item   color  object  price  new
# id
# 0       blue    ball    1.2   12
# 1      green     pen    1.0   12
# 2     yellow  pencil    0.6   12
# 3        red   paper    0.9   12
# 4      white     mug    1.7   12

# %%
frame['new'] = [3.0,1.3,2.2,0.8,1.1]

# %%
frame
# Out:
# item   color  object  price  new
# id
# 0       blue    ball    1.2  3.0
# 1      green     pen    1.0  1.3
# 2     yellow  pencil    0.6  2.2
# 3        red   paper    0.9  0.8
# 4      white     mug    1.7  1.1

# %%
# Membership of a Value

frame.isin([1.0,'pen'])
# Out:
# item  color  object  price    new
# id
# 0     False   False  False  False
# 1     False    True   True  False
# 2     False   False  False  False
# 3     False   False  False  False
# 4     False   False  False  False

# %%
frame[frame.isin([1.0,'pen'])]
# Out:
# item color object  price  new
# id
# 0      NaN    NaN    NaN  NaN
# 1      NaN    pen    1.0  NaN
# 2      NaN    NaN    NaN  NaN
# 3      NaN    NaN    NaN  NaN
# 4      NaN    NaN    NaN  NaN

# %%
#Deleting a Column

del frame['new']

frame
# Out:
# item   color  object  price
# id
# 0       blue    ball    1.2
# 1      green     pen    1.0
# 2     yellow  pencil    0.6
# 3        red   paper    0.9
# 4      white     mug    1.7

# %%
# DataFrame from Nested dict

nestdict = { 'red': { 2012: 22, 2013: 33 },
                     'white': { 2011: 13, 2012: 22, 2013: 16},
                     'blue': {2011: 17, 2012: 27, 2013: 18}}

# %%
nestdict
# Out:
# {'red': {2012: 22, 2013: 33},
#  'white': {2011: 13, 2012: 22, 2013: 16},
#  'blue': {2011: 17, 2012: 27, 2013: 18}}

# %%
frame2 = pd.DataFrame(nestdict)

# %%
frame2
# Out:
#        red  white  blue
# 2012  22.0     22    27
# 2013  33.0     16    18
# 2011   NaN     13    17

# %%
# Transposition of a DataFrame

frame2.T
# Out:
#        2012  2013  2011
# red    22.0  33.0   NaN
# white  22.0  16.0  13.0
# blue   27.0  18.0  17.0

# %% [markdown]
# **The Index Objects**
#
# The Index objects are responsible for the labels on the axes and other metadata as the name of the axes.
#
# You have already seen as an array containing labels is converted into an Index object: you need to specify the index option within the constructor.

# %%
ser = pd.Series([5,0,3,8,4], index=['red','blue','yellow','white','green'])
ser.index
# Out:
# Index(['red', 'blue', 'yellow', 'white', 'green'], dtype='object')

# %% [markdown]
# The Index objects are **immutable objects.** Once declared, these cannot be changed. This ensures their secure sharing between the various data structures.

# %% [markdown]
# **Methods on Index**
#
# There are some specific methods for indexes available to get some information about index from a data structure. For example, **idmin( ) and idmax( )** are two functions that return, respectively, the index with the lowest value and more.

# %%
ser.idxmin()
# Out:
# 'blue'

# %%
ser.idxmax()
# Out:
# 'white'

# %%
# Index with Duplicate Labels

serd = pd.Series(range(6), index=['white','white','blue','green','green','yellow'])
serd
# Out:
# white     0
# white     1
# blue      2
# green     3
# green     4
# yellow    5
# dtype: int64

# %%
serd['white']
# Out:
# white    0
# white    1
# dtype: int64

# %%
serd['green']
# Out:
# green    3
# green    4
# dtype: int64

# %%
serd.index.is_unique
# Out:
# False

# %%
frame.index.is_unique
# Out:
# True

# %% [markdown]
# **Other Functionalities on Indexes**
#
#
# Reindexing
#
# Dropping
#
# Alignment

# %%
# Reindexing

ser = pd.Series([2,5,7,4], index=['one','two','three','four'])
ser
# Out:
# one      2
# two      5
# three    7
# four     4
# dtype: int64

# %%
ser.reindex(['three','four','five','one'])
# Out:
# three    7.0
# four     4.0
# five     NaN
# one      2.0
# dtype: float64

# %%
ser3 = pd.Series([1,5,6,3],index=[0,3,5,6])

ser3
# Out:
# 0    1
# 3    5
# 5    6
# 6    3
# dtype: int64

# %% [markdown]
# As you can see in this example, the index column is not a perfect sequence of numbers; in fact there are some missing values **(1, 2, and 4).**
#
#  A common need would be to perform an interpolation in order to obtain the complete sequence of numbers.
#
# To achieve this you will use the reindexing with the **method option set to ffill.** Moreover, you need to set a range of values for indexes.
#
# In this case, for specifying a set of values **between 0 and 5,** you can use **range(6)** as argument.

# %%
ser3.reindex(range(6),method='ffill')
# Out:
# 0    1
# 1    1
# 2    1
# 3    5
# 4    5
# 5    6
# dtype: int64

# %% [markdown]
# As you can see from the result, the indexes that were not present in the original Series were added.
#
# By interpolation, those with the lowest index in the original Series, have been assigned as values.
#
# In fact the indexes 1 and 2 have the value 1 which belongs to index 0.
#
#
# If you want this index value to be assigned during the interpolation, you have to use the **bfill method.**

# %%
ser3.reindex(range(6),method='bfill')
# Out:
# 0    1
# 1    5
# 2    5
# 3    5
# 4    6
# 5    6
# dtype: int64

# %% [markdown]
# **Dropping**
#
# Another operation that is connected to Index objects is dropping. Deleting a row or a column becomes simple, precisely due to the labels used to indicate the indexes and column names.

# %%
import pandas as pd
import numpy as np
ser = pd.Series(np.arange(4.), index=['red','blue','yellow','white'])
ser
# Out:
# red       0.0
# blue      1.0
# yellow    2.0
# white     3.0
# dtype: float64

# %%
ser.drop('yellow')
# Out:
# red      0.0
# blue     1.0
# white    3.0
# dtype: float64

# %%
ser.drop(['blue','white'])
# Out:
# red       0.0
# yellow    2.0
# dtype: float64

# %% [markdown]
# **Arithmetic and Data Alignment**

# %%
s1 = pd.Series([3,2,5,1],['white','yellow','green','blue'])
s2 = pd.Series([1,4,7,2,1],['white','yellow','black','blue','brown'])

# %%
s1 + s2
# Out:
# black     NaN
# blue      3.0
# brown     NaN
# green     NaN
# white     4.0
# yellow    6.0
# dtype: float64

# %%
# matrix way

frame1 = pd.DataFrame(np.arange(16).reshape((4,4)),
                   index=['red','blue','yellow','white'],
                   columns=['ball','pen','pencil','paper'])

frame2 = pd.DataFrame(np.arange(12).reshape((4,3)),
                   index=['blue','green','white','yellow'],
                   columns=['mug','pen','ball'])

# %%
frame1
# Out:
#         ball  pen  pencil  paper
# red        0    1       2      3
# blue       4    5       6      7
# yellow     8    9      10     11
# white     12   13      14     15

# %%
frame2
# Out:
#         mug  pen  ball
# blue      0    1     2
# green     3    4     5
# white     6    7     8
# yellow    9   10    11

# %%
frame1 + frame2
# Out:
#         ball  mug  paper   pen  pencil
# blue     6.0  NaN    NaN   6.0     NaN
# green    NaN  NaN    NaN   NaN     NaN
# red      NaN  NaN    NaN   NaN     NaN
# white   20.0  NaN    NaN  20.0     NaN
# yellow  19.0  NaN    NaN  19.0     NaN

# %% [markdown]
# # Operations between Data Structures
#
#
# Flexible Arithmetic MethodsYou’ve just seen how to use mathematical operators directly on the pandas data structures.
#
# The same operations can also be performed using appropriate methods, called
# Flexible arithmetic methods.
#
# add( )
#
# sub( )
#
# div( )
#
# mul( )

# %%
frame1.add(frame2)
# Out:
#         ball  mug  paper   pen  pencil
# blue     6.0  NaN    NaN   6.0     NaN
# green    NaN  NaN    NaN   NaN     NaN
# red      NaN  NaN    NaN   NaN     NaN
# white   20.0  NaN    NaN  20.0     NaN
# yellow  19.0  NaN    NaN  19.0     NaN

# %%
frame = pd.DataFrame(np.arange(16).reshape((4,4)),
                   index=['red','blue','yellow','white'],
                   columns=['ball','pen','pencil','paper'])

ser = pd.Series(np.arange(4), index=['ball','pen','pencil','paper'])

# %%
frame - ser
# Out:
#         ball  pen  pencil  paper
# red        0    0       0      0
# blue       4    4       4      4
# yellow     8    8       8      8
# white     12   12      12     12

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **********************************************************

# %% [markdown]
# *********************************

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ****************************************************************

# %% [markdown]
# *********************************************

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Pandas: Reading and Writing Data**
#
#
#
# pandas is a library specialized for data analysis, so you expect that it is mainly focused on calculation and data processing.
#
# Moreover, even the process of writing and reading data from/to external files can be considered a part of the data processing.
#
#
# you can perform some operations in order to prepare the incoming data to further manipulations.
#
# this part is very important for data analysis and therefore a specific tool for this purpose must be present in the library pandas: a set of functions called I/O API.
#
#
# These functions are divided into two main categories, completely symmetrical to each other: **readers and writers.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
csvframe = pd.read_csv('/content/myCSV_01.csv')
csvframe
# Out:
#    white  red  blue  green animal
# 0      1    5     2      3    cat
# 1      2    7     8      5    dog
# 2      3    3     6      7  horse
# 3      2    2     8      3   duck
# 4      4    4     2      1  mouse

# %%
pd.read_table('/content/ch05_01.csv',sep=',')
# Out:
#    white  red  blue  green animal
# 0      1    5     2      3    cat
# 1      2    7     8      5    dog
# 2      3    3     6      7  horse
# 3      2    2     8      3   duck
# 4      4    4     2      1  mouse

# %%
pd.read_csv('/content/ch05_02.csv')
# Out:
#    1  5  2  3    cat
# 0  2  7  8  5    dog
# 1  3  3  6  7  horse
# 2  2  2  8  3   duck
# 3  4  4  2  1  mouse

# %%
pd.read_csv('/content/ch05_02.csv', header=None)
# Out:
#    0  1  2  3      4
# 0  1  5  2  3    cat
# 1  2  7  8  5    dog
# 2  3  3  6  7  horse
# 3  2  2  8  3   duck
# 4  4  4  2  1  mouse

# %%
pd.read_csv('/content/ch05_02.csv', names=['white','red','blue','green','animal'])
# Out:
#    white  red  blue  green animal
# 0      1    5     2      3    cat
# 1      2    7     8      5    dog
# 2      3    3     6      7  horse
# 3      2    2     8      3   duck
# 4      4    4     2      1  mouse

# %%
# Plain Text (txt) file format

# Suppose the above text written in a file called text.txt and you want to read this so you can refer the below code.

text_file = open("/content/text.txt", "r")
lines = text_file.read()
print(lines)
# Out:
# In my previous article, I introduced you to the basics of Apache Spark, different data representations
# (RDD / DataFrame / Dataset) and basics of operations (Transformation and Action). We even solved a machine
# learning problem from one of our past hackathons. In this article, I will continue from the place I left in
# my previous article. I will focus on manipulating RDD in PySpark by applying operations
# (Transformation and Actions).

# %%
# JSON file format

# Reading a JSON file

import pandas as pd 

df = pd.read_json("/content/train.json")
print(df)
# Out:
#                                       Employee
# 0  {'id': '1', 'Name': 'Ankit', 'Sal': '1000'}
# 1  {'id': '2', 'Name': 'Faizy', 'Sal': '2000'}

# %% [markdown]
# **HTML files**
#
#
# HTML stands for Hyper Text Markup Language.
#
# It is the standard markup language which is used for creating Web pages.
#
# HTML is used to describe structure of web pages using markup.
#
# HTML tags are same as XML but these are predefined.
#
# You can easily identify HTML document subsection on basis of tags such as represent the heading of HTML document.
#
# “paragraph” paragraph in HTML. HTML is not case sensitive.

# %%
# Reading the HTML file

#import the library used to query a website
import urllib.request


#specify the url
wiki = "https://en.wikipedia.org/wiki/List_of_state_and_union_territory_capitals_in_India"


#Query the website and return the html to the variable 'page'
page = urllib.request.urlopen(wiki)


#import the Beautiful soup functions to parse the data returned from the website
from bs4 import BeautifulSoup

#Parse the html in the 'page' variable, and store it in Beautiful Soup format
soup = BeautifulSoup(page)



# Use function “prettify” to look at nested structure of HTML page
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-disabled vector-feature-page-tools-pinned-disabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of state and union territory capitals in India - Wikipedia
#   </title>
#   <script>
# ...

# %%
print(soup.title)
# Out:
# <title>List of state and union territory capitals in India - Wikipedia</title>

# %%
print(soup.title.string)
# Out:
# List of state and union territory capitals in India - Wikipedia

# %%
# finding all the tables 

all_tables=soup.find_all('table')
all_tables
# Out:
# [<table class="sidebar nomobile nowraplinks"><tbody><tr><th class="sidebar-title"><a href="/wiki/States_and_union_territories_of_India" title="States and union territories of India">States and union <br/> territories of India</a> <br/> ordered by</th></tr><tr><td class="sidebar-image"><div class="center"><div class="floatnone"><a class="image" href="/wiki/File:Flag_of_India.svg"><img alt="Flag of India.svg" data-file-height="900" data-file-width="1350" decoding="async" height="47" src="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/70px-Flag_of_India.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/105px-Flag_of_India.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/140px-Flag_of_India.svg.png 2x" width="70"/></a></div></div></td></tr><tr><td class="sidebar-content hlist">
# ...

# %%
# Loading Images 
# importing matplotlib modules 
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 
  
# Read Images 
img = mpimg.imread('/content/dog.jpg') 
  
# Output Images 
plt.imshow(img)

# %%
# Data Preparation
# Merging 
# Concat
# Join
# Append


df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0 -0.976349  0.922781  1.373340 -1.032597
# 1 -1.585072  0.260423  0.839139 -1.086804
# 2 -1.409936  0.170593 -0.237242  0.140347
# 3 -0.798864  0.639717  0.972570  0.736073
# 4 -0.005702  0.884912 -0.085603  0.501699
# 5 -0.400441 -2.073005  1.796792  0.802912
# 6  0.371566  1.757164 -0.194682  0.483293
# 7 -0.288947 -0.246755 -0.269336  0.314616
# 8  0.341314 -0.310905  1.804318  0.205585
# 9 -1.499123  0.261322  0.551827 -0.802886

# %%
# break it into pieces
pieces = [df[:3], df[3:7], df[7:]]

pieces
# Out:
# [          0         1         2         3
#  0 -0.976349  0.922781  1.373340 -1.032597
#  1 -1.585072  0.260423  0.839139 -1.086804
#  2 -1.409936  0.170593 -0.237242  0.140347,
#            0         1         2         3
#  3 -0.798864  0.639717  0.972570  0.736073
#  4 -0.005702  0.884912 -0.085603  0.501699
#  5 -0.400441 -2.073005  1.796792  0.802912
#  6  0.371566  1.757164 -0.194682  0.483293,
#            0         1         2         3
#  7 -0.288947 -0.246755 -0.269336  0.314616
#  8  0.341314 -0.310905  1.804318  0.205585
#  9 -1.499123  0.261322  0.551827 -0.802886]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.976349  0.922781  1.373340 -1.032597
# 1 -1.585072  0.260423  0.839139 -1.086804
# 2 -1.409936  0.170593 -0.237242  0.140347
# 3 -0.798864  0.639717  0.972570  0.736073
# 4 -0.005702  0.884912 -0.085603  0.501699
# 5 -0.400441 -2.073005  1.796792  0.802912
# 6  0.371566  1.757164 -0.194682  0.483293
# 7 -0.288947 -0.246755 -0.269336  0.314616
# 8  0.341314 -0.310905  1.804318  0.205585
# 9 -1.499123  0.261322  0.551827 -0.802886

# %%
# Join

left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})

right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
# Append

df = pd.DataFrame(np.random.randn(8, 4), columns=['A','B','C','D'])

df
# Out:
#           A         B         C         D
# 0  0.130474 -0.907605  0.044941  1.356903
# 1 -0.044848 -0.430153 -1.519094  2.017740
# 2  2.754140 -1.107594 -0.592332  0.376198
# 3 -0.104098  0.636993  1.892739 -0.160354
# 4  1.267386 -1.483913 -0.411080  0.915478
# 5  0.137304  0.245628  0.463855  1.314136
# 6  0.146114 -0.718128 -1.404081  0.232049
# 7  0.932621 -0.646479 -1.788832 -2.203580

# %%
s = df.iloc[3]
s
# Out:
# A   -0.104098
# B    0.636993
# C    1.892739
# D   -0.160354
# Name: 3, dtype: float64

# %%
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0  0.130474 -0.907605  0.044941  1.356903
# 1 -0.044848 -0.430153 -1.519094  2.017740
# 2  2.754140 -1.107594 -0.592332  0.376198
# 3 -0.104098  0.636993  1.892739 -0.160354
# 4  1.267386 -1.483913 -0.411080  0.915478
# 5  0.137304  0.245628  0.463855  1.314136
# 6  0.146114 -0.718128 -1.404081  0.232049
# 7  0.932621 -0.646479 -1.788832 -2.203580
# 8 -0.104098  0.636993  1.892739 -0.160354

# %%
# Removing Duplicates
# Consider dataset containing ramen rating.

df = pd.DataFrame({
    'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie'],
    'style': ['cup', 'cup', 'cup', 'pack', 'pack'],
    'rating': [4, 4, 3.5, 15, 5]})



df
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
df.drop_duplicates()
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
df.drop_duplicates(subset=['brand'])
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5

# %%
# To remove duplicates and keep last occurrences, use keep.

df.drop_duplicates(subset=['brand', 'style'], keep='last')
# Out:
#      brand style  rating
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 4  Indomie  pack     5.0
